# %% [markdown]
# <a href="https://colab.research.google.com/github/qinchaojie/colabNotebooks/blob/main/opencv_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


x = np.random.randint(10)
x
# Out:
# 5

# %%
sflja asfhjhfafhaKVFA
